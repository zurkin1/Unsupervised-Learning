# %%
# !git clone https://github.com/facebookresearch/swav
# Out:
# Cloning into 'swav'...
# remote: Enumerating objects: 163, done.
# remote: Counting objects: 100% (96/96), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 163 (delta 77), reused 63 (delta 63), pack-reused 67
# Receiving objects: 100% (163/163), 65.50 KiB | 1.04 MiB/s, done.
# Resolving deltas: 100% (111/111), done.

# %%
# !git clone "https://github.com/NVIDIA/apex"
# Out:
# Cloning into 'apex'...
# remote: Enumerating objects: 11632, done.
# remote: Counting objects: 100% (3700/3700), done.
# remote: Compressing objects: 100% (563/563), done.
# remote: Total 11632 (delta 3341), reused 3264 (delta 3134), pack-reused 7932
# Receiving objects: 100% (11632/11632), 15.46 MiB | 20.15 MiB/s, done.
# Resolving deltas: 100% (8170/8170), done.

# %%
# !pip install -v --disable-pip-version-check --no-build-isolation --no-cache-dir /content/apex
# Out:
# Using pip 23.1.2 from /usr/local/lib/python3.10/dist-packages/pip (python 3.10)
# Processing ./apex
#   Running command Preparing metadata (pyproject.toml)
#   No CUDA runtime is found, using CUDA_HOME='/usr/local/cuda'
#
# ...
#    If your intention is to cross-compile, this is not an error.
#   By default, Apex will cross-compile for Pascal (compute capabilities 6.0, 6.1, 6.2),
#   Volta (compute capability 7.0), Turing (compute capability 7.5),
#   and, if the CUDA version is >= 11.0, Ampere (compute capability 8.0).
#   If you wish to cross-compile for a single specific architecture,
#   export TORCH_CUDA_ARCH_LIST="compute capability" before running setup.py.
#
#
#
#   torch.__version__  = 2.1.0+cu121
#
#
#   running dist_info
#   creating /tmp/pip-modern-metadata-yawhxqun/apex.egg-info
#   writing /tmp/pip-modern-metadata-yawhxqun/apex.egg-info/PKG-INFO
#   writing dependency_links to /tmp/pip-modern-metadata-yawhxqun/apex.egg-info/dependency_links.txt
# ...

# %%
# !unzip /content/archive.zip

# %%
# !python -m torch.distributed.launch --nproc_per_node=8 /content/swav/main_swav.py \
--data_path /content/data/images/train \
--epochs 400 \
--base_lr 0.6 \
--final_lr 0.0006 \
--warmup_epochs 0 \
--batch_size 32 \
--size_crops 224 96 \
--nmb_crops 2 6 \
--min_scale_crops 0.14 0.05 \
--max_scale_crops 1. 0.14 \
--use_fp16 true \
--freeze_prototypes_niters 5005 \
--queue_length 3840 \
--epoch_queue_starts 15
# Out:
# Traceback (most recent call last):
#   File "/content/swav/main_swav.py", line 380, in <module>
#     main()
#   File "/content/swav/main_swav.py", line 126, in main
#     init_distributed_mode(args)
#   File "/content/swav/src/utils.py", line 56, in init_distributed_mode
#     args.rank = int(os.environ["RANK"])
#   File "/usr/lib/python3.10/os.py", line 680, in __getitem__
#     raise KeyError(key) from None
# KeyError: 'RANK'
